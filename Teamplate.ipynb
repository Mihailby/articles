# %%
# Install dependencies
# %pip install -q amplpy

# Google Colab & Kaggle integration
from amplpy import AMPL, ampl_notebook
ampl = ampl_notebook(
    modules=["gurobi", "coin", "highs", "gokestrel"], # modules to install
    license_uuid="") # license to use
# Out:
# Licensed to AMPL Community Edition License for <mikhail@ampl.com>.

# %% [markdown]
# <svg width="24" height="24" style="color: inherit;">
#   <path fill="currentColor" d="M12 2C6.48 2 2 6.48..."/>
# </svg>
